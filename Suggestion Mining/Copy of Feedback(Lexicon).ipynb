# %%
import pandas as pd
from google.colab import drive
import re
import spacy
from spacy.util import minibatch, compounding
import random
from spacy.training import Example
from spacy.tokens import DocBin
from spacy.util import filter_spans
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix

# %%
drive.mount('/content/drive/')

# %cd drive/MyDrive/Text Mining Project
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/Text Mining Project'
# /content/drive/MyDrive/Text Mining Project

# %%
file_path = 'datasetV2.csv'

df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                                                 text  label
# 0  The in-app chat support feature is incredibly ...      1
# 1  The ability to track multiple orders simultane...      1
# 2  I suggest adding a feature to customize delive...      1
# 3  Providing estimated delivery times for each re...      1
# 4  Offering discounts for frequent users would en...      1

# %% [markdown]
# ## Preprocessing

# %%
def clean_text(text):
    # Remove special characters and extra whitespace
    cleaned_text = re.sub(r'[^A-Za-z0-9\s\.]', '', text)
    # Convert multiple whitespace characters into a single space
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    # Convert text to lowercase
    cleaned_text = cleaned_text.lower()
    return cleaned_text

# %%
df['text'] = df['text'].apply(clean_text)

# %% [markdown]
# ## Model

# %%
def identify_constructive_feedback(review):
    constructive_keywords = [
        "improve", "enhance", "fix", "change", "update", "adjust", "revise", "modify",
        "suggest", "recommend", "advise", "encourage", "strengthen",
        "clarify", "consider", "explore", "rework", "optimize",
        "feature", "bug", "performance", "interface",
        "usability", "navigation", "speed", "loading", "responsiveness",
        "compatibility", "security", "privacy", "feedback", "review", "rating",
        "test", "stability", "crash", "error",
        "warning", "notification", "settings", "behavior", "timing", "request",
        "design", "layout", "functionality", "user-friendly", "efficiency",
        "error-free", "smooth", "streamlined", "robust", "intuitive", "suggestion",
        "recommendation", "problem", "issue", "request", "requesting", "need", "demand",
        "suggestion", "idea", "solution", "enhancement", "modification", "adjustment",
        "change", "update", "revision", "upgrade", "overhaul", "redo", "remake", "redo",
        "enhance", "upgrade", "overhaul", "redo", "redesign", "revamp", "amend",
        "rethink", "reconsider", "refinement", "overcome", "innovation", "progress",
        "innovative", "evolve", "streamline", "enhanced", "optimized", "improved",
        "upgraded", "redesigned", "revamped", "amended", "refined", "innovated",
        "evolved", "streamlined", "effortless", "flawless", "smooth", "intuitive",
        "user-friendly", "friendly", "easy-to-use", "usable", "effective", "efficient",
        "effective", "efficient", "convenient", "seamless", "quick", "responsive",
        "stable", "reliable", "secure", "private", "protected", "protected", "consistent",
        "satisfactory", "satisfaction", "pleasant", "enjoyable", "helpful", "useful",
        "valuable", "valued", "beneficial", "advantageous", "superior", "quality",
        "high-quality", "premium", "exceptional", "excellent", "outstanding", "remarkable",
        "fantastic", "awesome", "wonderful", "amazing", "impressive", "brilliant",
        "stellar", "great", "good", "well", "positive", "favorable", "constructive"
    ]


    for keyword in constructive_keywords:
        if keyword in review:
            return 1

    return 0

# %%
X_test = df['text']
y_test = df['label']

# %%
y_pred = []

for text in X_test:
    prediction = identify_constructive_feedback(text)
    y_pred.append(prediction)

# %%
print(classification_report(y_test,y_pred))
print('Confusion Matrix:',confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.55      0.54        94
#            1       0.68      0.66      0.67       138
#
#     accuracy                           0.62       232
#    macro avg       0.60      0.61      0.61       232
# weighted avg       0.62      0.62      0.62       232
#
# Confusion Matrix: [[52 42]
#  [47 91]]

# %%
auc_score = roc_auc_score(y_test, y_pred)
print(f'AUC Score: {auc_score}')
# Out:
# AUC Score: 0.6063058896083874

# %%
feedbacks = []

for text, prediction in zip(X_test, y_pred):
    if prediction == 1:
      feedbacks.append(text)

feedbacks
# Out:
# ['the inapp chat support feature is incredibly helpful.',
#  'the ability to track multiple orders simultaneously would be beneficial.',
#  'i suggest adding a feature to customize delivery instructions.',
#  'providing estimated delivery times for each restaurant would improve transparency.',
#  'offering discounts for frequent users would encourage loyalty.',
#  'the apps search function needs refinement for better results.',
#  'ive experienced issues with payment processing which is frustrating.',
#  'the latest update has introduced bugs making the app unusable.',
#  'the app lacks a feature to reorder previous orders easily.',
#  'a feature to rate specific items within an order would provide valuable feedback.',
#  'the apps notification system needs improvement for timely updates.',
#  'adding a dark mode option would be great for nighttime usage.',
#  'the apps loading times are frustratingly slow.',
#  'the customer support team is unresponsive to inquiries.',
#  'the apps layout could be more visually appealing.',
#  'the app should provide recommendations based on past orders.',
#  'the delivery tracking map doesnt update in realtime.',
#  'the apps language translation feature is inaccurate.',
#  'the option to schedule orders in advance would be convenient.',
#  'the apps customer support chatbot is not helpful.',
#  'implementing a feature to order for pickup would be useful.',
#  'the app crashes every time i try to add a new address.',
#  'adding a feature to track loyalty points would incentivize repeat orders.',
#  'the apps tutorial for new users is unclear and needs improvement.',
#  'there should be an option to leave feedback for specific restaurants.',
#  'offering discounts during offpeak hours would help distribute demand.',
#  'there should be a way to filter restaurants based on their hygiene ratings.',
#  'the apps loading animation is distracting and unnecessary.',
#  'the apps location accuracy needs improvement for accurate pickup points.',
#  'adding an option to preselect favorite items for faster ordering would be convenient.',
#  'the apps notification sound is too loud and cannot be adjusted.',
#  'the apps layout could be optimized for larger screens on tablets.',
#  'the apps language localization feature is incomplete and inconsistent.',
#  'the apps support documentation is outdated and does not address current issues.',
#  'adding a feature to track the environmental impact of deliveries would be informative.',
#  'the apps map navigation feature often suggests longer routes.',
#  'the apps loading screen should display helpful tips or promotions.',
#  'the apps voice recognition feature misunderstands commands frequently.',
#  'providing realtime updates on order preparation status would reduce uncertainty.',
#  'there should be an option to review and edit orders before finalizing.',
#  'implementing a feature to request specific delivery time slots would be convenient.',
#  'the apps chat support feature often disconnects unexpectedly.',
#  'the apps onboarding process should include a tour of key features.',
#  'there should be an option to set dietary preferences for personalized restaurant suggestions.',
#  'adding a feature to split bills among group orders would be practical.',
#  'the apps loading animation is outdated and could be more engaging.',
#  'the apps notifications should include previews of messages for convenience.',
#  'adding a feature to track delivery progress on a map in realtime would be useful.',
#  'the apps loading times are excessively long especially during peak hours.',
#  'the apps customer rating system should consider both driver and restaurant performance.',
#  'the apps order tracking feature should provide estimated arrival times with greater accuracy.',
#  'adding a feature to request contactless delivery would address current safety concerns.',
#  'the apps loading screen should display informative tips or facts to engage users.',
#  'the apps photo upload feature for user reviews should support higher resolution images.',
#  'there should be an option to rate the quality of customer service received from support agents.',
#  'the apps user interface should include a dark mode option for reduced eye strain.',
#  'the apps inapp navigation feature should support alternate routes for better efficiency.',
#  'there should be an option to filter restaurants based on their ecofriendly packaging options.',
#  'the apps customer support response times should be displayed in the chat interface.',
#  'there should be an option to provide feedback on individual menu items for restaurant improvement.',
#  'the apps notification system should include reminders for upcoming scheduled orders.',
#  'the apps rating system should include more detailed criteria for better feedback.',
#  'the apps location accuracy should be improved for smoother pickup and dropoff experiences.',
#  'adding a feature to reorder previous group orders would simplify the process for social gatherings.',
#  'the apps loading animation should be optimized for faster loading times.',
#  'the apps checkout process should offer guest checkout as a quick option for new users.',
#  'there should be an option to provide feedback on the condition of delivered food items.',
#  'the apps customer support chat feature should include automated responses for common inquiries.',
#  'the apps loading screen should display helpful tips or facts related to the service.',
#  'there should be an option to provide feedback on the accuracy of order fulfillment.',
#  'the apps loading animation should be visually appealing to enhance user experience.',
#  'there should be an option to request contactless payment methods for added safety.',
#  'there should be an option to rate the speed of delivery for each order.',
#  'the apps customer support chat feature should include realtime typing indicators.',
#  'there should be an option to filter restaurants based on their ratings and reviews.',
#  'the apps loading screen should include progress indicators for better user feedback.',
#  'there should be an option to customize push notification settings for personalized alerts.',
#  'the apps loading animation should be interactive to keep users engaged.',
#  'the apps search feature should allow filtering by distance from current location.',
#  'adding a feature to save favorite restaurants for quick access would be convenient.',
#  'the apps customer support should include a callback option for urgent issues.',
#  'there should be an option to provide feedback on the accuracy of delivery addresses.',
#  'the apps loading screen should display interesting facts or trivia related to food.',
#  'there should be an option to customize notification preferences for order updates.',
#  'the apps customer rating system should be transparent with clear criteria for ratings.',
#  'adding a feature to track delivery drivers estimated arrival times would be helpful.',
#  'the apps customer support should provide a satisfaction survey after each interaction.',
#  'the apps tutorial for new users should include interactive walkthroughs for key features.',
#  'there should be an option to rate the cleanliness of restaurants for user feedback.',
#  'the apps loading animation should be customizable with different themes for user preference.',
#  'there should be an option to provide feedback on the ease of use of the apps interface.',
#  'there should be an option to filter restaurants based on their acceptance of special requests.',
#  'the apps loading screen should display motivational quotes or tips to engage users.',
#  'the apps customer support should include a chatbot for quick answers to common questions.',
#  'there should be an option to provide feedback on the variety of cuisines available on the app.',
#  'the apps loading animation should include progress indicators for better user feedback.',
#  'the apps customer support should include video chat for visual assistance when needed.',
#  'there should be an option to provide feedback on the responsiveness of restaurant staff.',
#  'the apps loading screen should display interesting facts or trivia about the service.',
#  'there should be an option to provide feedback on the quality of packaging for delivered orders.',
#  'the apps loading animation should be interactive to keep users engaged during wait times.',
#  'there should be an option to rate the speed of customer service response times.',
#  'there should be an option to provide feedback on the accuracy of menu item descriptions.',
#  'the apps loading screen should display tips or suggestions for getting the most out of the service.',
#  'there should be an option to provide feedback on the speed of delivery for orders.',
#  'the apps loading animation should be customizable with different animations for variety.',
#  'the apps customer support should offer live chat for immediate assistance with issues.',
#  'there should be an option to provide feedback on the accuracy of restaurant location information.',
#  'the apps loading screen should display user testimonials or success stories for inspiration.',
#  'there should be an option to provide feedback on the ease of navigation within the app.',
#  'the apps loading animation should include interactive elements for user engagement.',
#  'there should be an option to rate the overall satisfaction with the apps user experience.',
#  'the apps customer support should include a feedback form for continuous improvement.',
#  'there should be an option to provide feedback on the availability of promotions and discounts.',
#  'the apps loading screen should display tips or suggestions for optimizing order experiences.',
#  'the app frequently crashes upon opening making it unusable.',
#  'the customer support team was unresponsive to my inquiries.',
#  'the apps interface is cluttered and confusing to navigate.',
#  'the app logged me out without warning losing my order progress.',
#  'the customer support representative was dismissive and unhelpful.',
#  'the app doesnt offer refunds for incorrect or missing orders frustrating policy.',
#  'the food quality was subpar and not worth the price paid.',
#  'the delivery was delayed without any notification or explanation.',
#  'the apps search function doesnt return relevant results frustrating experience.',
#  'the apps checkout process is slow and cumbersome needs improvement.',
#  'the apps customer support chatbot is unhelpful and provides generic responses.',
#  'the apps interface is outdated and lacks modern features.',
#  'the apps payment processing is unreliable causing failed transactions.',
#  'the app doesnt provide updates on delayed orders leaving customers in the dark.',
#  'the restaurant forgot to include utensils with the order inconvenient.',
#  'the apps loading times are excessively long frustrating to use.',
#  'the apps customer support team is unhelpful and lacks empathy.',
#  'the apps search results are inconsistent and often display irrelevant options.']
